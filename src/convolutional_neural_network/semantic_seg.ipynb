# %%
import numpy as np
import imageio
import os
import torch
from torch import nn, optim
import matplotlib.pyplot as plt
import subprocess
from torchmetrics.functional import dice

# %%
def load_image():

    if not os.path.exists("WARWICK"):
        print("Extracting WARWICK dataset...")
        subprocess.run('unzip ../../datasets/WARWICK.zip', shell=True, check=True)
        print("Done!")
        
    # Loads the MNIST dataset from png images
 
    NUM_TRAIN = 85
    NUM_TEST = 60 
    # create list of image objects
    test_images = []
    test_labels = []    
    
    for idx in range(1, NUM_TEST+1):
        prefix_test = "WARWICK/Test/image_0" if idx < 10 else "WARWICK/Test/image_"
        prefix_label = "WARWICK/Test/label_0" if idx < 10 else "WARWICK/Test/label_"
        image_path_test = prefix_test + str(idx) + ".png"
        image_path_label = prefix_label + str(idx) + ".png"
        image = imageio.imread(image_path_test)
        test_images.append(image)
        label = imageio.imread(image_path_label)
        test_labels.append(label)  
            
    # create list of image objects
    train_images = []
    train_labels = []    

    for idx in range(1, NUM_TRAIN+1):
        prefix_test = "WARWICK/Train/image_0" if idx < 10 else "WARWICK/Train/image_"
        prefix_label = "WARWICK/Train/label_0" if idx < 10 else "WARWICK/Train/label_"
        image_path_test = prefix_test + str(idx) + ".png"
        image_path_label = prefix_label + str(idx) + ".png"
        image = imageio.imread(image_path_test)
        train_images.append(image)
        label = imageio.imread(image_path_label)
        train_labels.append(label)                  
    
    return train_images, train_labels, test_images, test_labels

# %%
# load image data
X_train, Y_train, X_test, Y_test = load_image()

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
# move data to the device
X_train = torch.from_numpy(np.array(X_train)).float().to(device)
Y_train = torch.from_numpy(np.array(Y_train)).float().to(device)
X_test = torch.from_numpy(np.array(X_test)).float().to(device)
Y_test = torch.from_numpy(np.array(Y_test)).float().to(device)

print(X_train.shape)
# Out:
# torch.Size([85, 128, 128, 3])

# %%
#display an sample image and its label

plt.imshow(X_train[19].cpu().squeeze().numpy()/255, cmap='gray')
plt.axis('off')
plt.show()

plt.imshow(Y_train[19].cpu().squeeze().numpy(), cmap='gray')
plt.axis('off')
plt.show()

# %%
# Reshape the data to 4D tensor - (sample_number, num_channels, x_img_size, y_img_size)
X_train = X_train.permute(0, 3, 1, 2)
X_test = X_test.permute(0, 3, 1, 2)

Y_train.unsqueeze_(1)
Y_test.unsqueeze_(1)

print(X_train.shape)
print(Y_train.shape)

# Normalize the data
X_train = X_train/255.0
X_test = X_test/255.0
Y_train = Y_train/255.0
Y_test = Y_test/255.0
# Out:
# torch.Size([85, 3, 128, 128])
# torch.Size([85, 1, 128, 128])

# %%
# reshape true labels to 2-channel tensor - (sample_number, num_classes, image_height, image_width)
n, c, h, w = Y_train.shape

tmp = torch.zeros(n, 2, h, w, device=device)
tmp[:, 0, :, :][Y_train[:, 0, :, :]==0] = 1
tmp[:, 1, :, :][Y_train[:, 0, :, :]==1] = 1

Y_train = tmp
n, c, h, w = Y_test.shape
tmp = torch.zeros(n, 2, h, w, device=device)
tmp[:, 0, :, :][Y_test[:, 0, :, :]==0] = 1
tmp[:, 1, :, :][Y_test[:, 0, :, :]==1] = 1
Y_test = tmp

# %%
os.environ['PYTORCH_CUDA_ALLOC_CONF'] = 'max_split_size_mb:512'

# define the model
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Sequential(         
            nn.Conv2d(
                in_channels=3,              
                out_channels=32,            
                kernel_size=3,              
                stride=1,                   
                padding=1,                  
            ),                              
            nn.ReLU(),                      
            nn.MaxPool2d(kernel_size=2, stride=2),  
            nn.ConvTranspose2d(32, 64, 3, 2, 1, 1),  
        )
        self.conv2 = nn.Sequential(         
            nn.Conv2d(64, 32, 3, 1, 1),     
            nn.ReLU(),                      
            nn.MaxPool2d(2),
            nn.ConvTranspose2d(32, 64, 3, 2, 1, 1),              
        )
        self.conv3 = nn.Sequential(         
            nn.Conv2d(64, 32, 3, 1, 1),     
            nn.ReLU(),                      
        )
        # 1*1 convolution kernel
        self.out = nn.Conv2d(32, out_channels=2, kernel_size=(1, 1), stride=(1, 1), padding=(0, 0), bias=False)
    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        
        output = self.out(x)
        return output

# define the accuracy function
def acc_fn(y_pred, y_true):
    dice_scores =[]
    y_pred = torch.softmax(y_pred, dim=1)
    y_pred = torch.argmax(y_pred, dim=1)
    y_true_label = torch.argmax(y_true, dim=1)
    for i in range(len(y_pred)):
        dice_score = dice(y_pred[i].int(), y_true_label[i].int(), num_classes=2)
        dice_scores.append(dice_score)

    return torch.mean(torch.stack(dice_scores))

# define the training function
def model_train(model, X_train, Y_train, X_test, Y_test, n_epochs,  loss_fn, optimizer, batch_size=5):
    losses_train, losses_test, acc_train, acc_test = [], [], [], []
    batch_start = torch.arange(0, len(X_train), batch_size)

    model.train()
    for epoch in range(n_epochs):
        for start in batch_start:
            X_batch = X_train[start:start+batch_size]
            Y_batch = Y_train[start:start+batch_size]
            y_pred = model(X_batch)
            loss = loss_fn(y_pred, Y_batch)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
        
        with torch.no_grad():
            y_pred_train = model(X_train)
            y_pred_test = model(X_test)
        losses_train.append(loss_fn(y_pred_train, Y_train).item())
        losses_test.append(loss_fn(y_pred_test, Y_test).item())
        acc_train.append(acc_fn(y_pred_train, Y_train).item())
        acc_test.append(acc_fn(y_pred_test, Y_test).item())
        print(f'Finished epoch {epoch}, train loss {losses_train[-1]:.4f}, test loss {losses_test[-1]:.4f}, \
           train acc {acc_train[-1]:.4f}, test acc {acc_test[-1]:.4f}')
    return losses_train, losses_test, acc_train, acc_test

# define the prediction function
def predict(model, X):
    model.eval()
    with torch.no_grad():
        y_pred = model(X)#['out']
        y_pred = torch.argmax(torch.softmax(y_pred, dim=1), dim=1)
    return y_pred

# %%
# initialize the model
model = CNN()
model = model.to(device)
print(model)

n_epochs = 100
learning_rate = 0.001
batch_size = 10

loss_fn   = nn.CrossEntropyLoss(reduction='mean')
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
losses_train, losses_test, acc_train, acc_test = model_train(model, X_train, Y_train, X_test, Y_test,
                                                            n_epochs=n_epochs,
                                                            loss_fn=loss_fn,
                                                            optimizer=optimizer,
                                                            batch_size=batch_size)
# Out:
# CNN(
#   (conv1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): ConvTranspose2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#   )
#   (conv2): Sequential(
#     (0): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): ConvTranspose2d(32, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), output_padding=(1, 1))
#   )
#   (conv3): Sequential(
#     (0): Conv2d(64, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU()
#   )
#   (out): Conv2d(32, 2, kernel_size=(1, 1), stride=(1, 1), bias=False)
# )
# Finished epoch 0, train loss 0.6914, test loss 0.6938,            train acc 0.5160, test acc 0.4926
# Finished epoch 1, train loss 0.6823, test loss 0.6991,            train acc 0.5207, test acc 0.4589
# Finished epoch 2, train loss 0.6450, test loss 0.6859,            train acc 0.6451, test acc 0.5398
# Finished epoch 3, train loss 0.6091, test loss 0.6821,            train acc 0.6722, test acc 0.5988
# Finished epoch 4, train loss 0.5906, test loss 0.7096,            train acc 0.6902, test acc 0.6038
# Finished epoch 5, train loss 0.5758, test loss 0.6724,            train acc 0.7032, test acc 0.6149
# Finished epoch 6, train loss 0.5616, test loss 0.6667,            train acc 0.7126, test acc 0.6211
# Finished epoch 7, train loss 0.5527, test loss 0.6700,            train acc 0.7102, test acc 0.6191
# Finished epoch 8, train loss 0.5405, test loss 0.6342,            train acc 0.7134, test acc 0.6368
# Finished epoch 9, train loss 0.5346, test loss 0.6360,            train acc 0.7260, test acc 0.6441
# Finished epoch 10, train loss 0.5256, test loss 0.6141,            train acc 0.7297, test acc 0.6548
# Finished epoch 11, train loss 0.5201, test loss 0.6121,            train acc 0.7374, test acc 0.6602
# Finished epoch 12, train loss 0.5135, test loss 0.5954,            train acc 0.7446, test acc 0.6751
# Finished epoch 13, train loss 0.5085, test loss 0.5836,            train acc 0.7504, test acc 0.6895
# Finished epoch 14, train loss 0.5054, test loss 0.5749,            train acc 0.7533, test acc 0.7048
# Finished epoch 15, train loss 0.5034, test loss 0.5638,            train acc 0.7547, test acc 0.7173
# Finished epoch 16, train loss 0.5006, test loss 0.5579,            train acc 0.7582, test acc 0.7233
# Finished epoch 17, train loss 0.4982, test loss 0.5481,            train acc 0.7611, test acc 0.7299
# Finished epoch 18, train loss 0.4980, test loss 0.5480,            train acc 0.7587, test acc 0.7338
# Finished epoch 19, train loss 0.4922, test loss 0.5388,            train acc 0.7669, test acc 0.7440
# Finished epoch 20, train loss 0.4873, test loss 0.5373,            train acc 0.7706, test acc 0.7348
# Finished epoch 21, train loss 0.4846, test loss 0.5359,            train acc 0.7727, test acc 0.7432
# Finished epoch 22, train loss 0.4809, test loss 0.5318,            train acc 0.7752, test acc 0.7441
# Finished epoch 23, train loss 0.4758, test loss 0.5285,            train acc 0.7791, test acc 0.7445
# Finished epoch 24, train loss 0.4718, test loss 0.5279,            train acc 0.7820, test acc 0.7448
# Finished epoch 25, train loss 0.4723, test loss 0.5192,            train acc 0.7821, test acc 0.7565
# Finished epoch 26, train loss 0.4719, test loss 0.5250,            train acc 0.7818, test acc 0.7560
# Finished epoch 27, train loss 0.4642, test loss 0.5249,            train acc 0.7864, test acc 0.7401
# Finished epoch 28, train loss 0.4608, test loss 0.5133,            train acc 0.7904, test acc 0.7570
# Finished epoch 29, train loss 0.4647, test loss 0.5111,            train acc 0.7866, test acc 0.7646
# Finished epoch 30, train loss 0.4620, test loss 0.5229,            train acc 0.7897, test acc 0.7545
# Finished epoch 31, train loss 0.4552, test loss 0.5079,            train acc 0.7942, test acc 0.7590
# Finished epoch 32, train loss 0.4552, test loss 0.5013,            train acc 0.7942, test acc 0.7699
# Finished epoch 33, train loss 0.4599, test loss 0.5096,            train acc 0.7881, test acc 0.7641
# Finished epoch 34, train loss 0.4497, test loss 0.5029,            train acc 0.7983, test acc 0.7645
# Finished epoch 35, train loss 0.4464, test loss 0.4967,            train acc 0.8005, test acc 0.7715
# Finished epoch 36, train loss 0.4510, test loss 0.4946,            train acc 0.7946, test acc 0.7724
# Finished epoch 37, train loss 0.4479, test loss 0.5007,            train acc 0.7974, test acc 0.7686
# Finished epoch 38, train loss 0.4412, test loss 0.4977,            train acc 0.8030, test acc 0.7670
# Finished epoch 39, train loss 0.4384, test loss 0.4857,            train acc 0.8050, test acc 0.7775
# Finished epoch 40, train loss 0.4443, test loss 0.4887,            train acc 0.7980, test acc 0.7746
# Finished epoch 41, train loss 0.4376, test loss 0.4951,            train acc 0.8049, test acc 0.7709
# Finished epoch 42, train loss 0.4331, test loss 0.4870,            train acc 0.8077, test acc 0.7738
# Finished epoch 43, train loss 0.4317, test loss 0.4734,            train acc 0.8081, test acc 0.7838
# Finished epoch 44, train loss 0.4380, test loss 0.4919,            train acc 0.8014, test acc 0.7705
# Finished epoch 45, train loss 0.4273, test loss 0.4883,            train acc 0.8111, test acc 0.7736
# Finished epoch 46, train loss 0.4239, test loss 0.4777,            train acc 0.8127, test acc 0.7796
# Finished epoch 47, train loss 0.4248, test loss 0.4744,            train acc 0.8109, test acc 0.7804
# Finished epoch 48, train loss 0.4303, test loss 0.4884,            train acc 0.8058, test acc 0.7702
# Finished epoch 49, train loss 0.4204, test loss 0.4789,            train acc 0.8141, test acc 0.7777
# Finished epoch 50, train loss 0.4181, test loss 0.4678,            train acc 0.8156, test acc 0.7843
# Finished epoch 51, train loss 0.4211, test loss 0.4746,            train acc 0.8118, test acc 0.7768
# Finished epoch 52, train loss 0.4201, test loss 0.4795,            train acc 0.8124, test acc 0.7748
# Finished epoch 53, train loss 0.4137, test loss 0.4696,            train acc 0.8174, test acc 0.7824
# Finished epoch 54, train loss 0.4117, test loss 0.4584,            train acc 0.8186, test acc 0.7891
# Finished epoch 55, train loss 0.4150, test loss 0.4738,            train acc 0.8145, test acc 0.7767
# Finished epoch 56, train loss 0.4120, test loss 0.4716,            train acc 0.8170, test acc 0.7800
# Finished epoch 57, train loss 0.4072, test loss 0.4660,            train acc 0.8201, test acc 0.7844
# Finished epoch 58, train loss 0.4056, test loss 0.4572,            train acc 0.8211, test acc 0.7894
# Finished epoch 59, train loss 0.4083, test loss 0.4657,            train acc 0.8184, test acc 0.7833
# Finished epoch 60, train loss 0.4071, test loss 0.4711,            train acc 0.8190, test acc 0.7802
# Finished epoch 61, train loss 0.4017, test loss 0.4597,            train acc 0.8231, test acc 0.7888
# Finished epoch 62, train loss 0.4002, test loss 0.4543,            train acc 0.8238, test acc 0.7917
# Finished epoch 63, train loss 0.4034, test loss 0.4646,            train acc 0.8208, test acc 0.7844
# Finished epoch 64, train loss 0.4011, test loss 0.4660,            train acc 0.8223, test acc 0.7843
# Finished epoch 65, train loss 0.3966, test loss 0.4562,            train acc 0.8255, test acc 0.7911
# Finished epoch 66, train loss 0.3954, test loss 0.4510,            train acc 0.8261, test acc 0.7937
# Finished epoch 67, train loss 0.3983, test loss 0.4592,            train acc 0.8238, test acc 0.7883
# Finished epoch 68, train loss 0.3960, test loss 0.4615,            train acc 0.8249, test acc 0.7875
# Finished epoch 69, train loss 0.3918, test loss 0.4509,            train acc 0.8280, test acc 0.7949
# Finished epoch 70, train loss 0.3913, test loss 0.4503,            train acc 0.8278, test acc 0.7945
# Finished epoch 71, train loss 0.3936, test loss 0.4561,            train acc 0.8262, test acc 0.7908
# Finished epoch 72, train loss 0.3913, test loss 0.4567,            train acc 0.8273, test acc 0.7910
# Finished epoch 73, train loss 0.3877, test loss 0.4469,            train acc 0.8300, test acc 0.7974
# Finished epoch 74, train loss 0.3877, test loss 0.4483,            train acc 0.8294, test acc 0.7960
# Finished epoch 75, train loss 0.3900, test loss 0.4527,            train acc 0.8279, test acc 0.7932
# Finished epoch 76, train loss 0.3871, test loss 0.4532,            train acc 0.8296, test acc 0.7933
# Finished epoch 77, train loss 0.3841, test loss 0.4446,            train acc 0.8317, test acc 0.7989
# Finished epoch 78, train loss 0.3845, test loss 0.4452,            train acc 0.8311, test acc 0.7982
# Finished epoch 79, train loss 0.3864, test loss 0.4519,            train acc 0.8295, test acc 0.7938
# Finished epoch 80, train loss 0.3827, test loss 0.4469,            train acc 0.8321, test acc 0.7978
# Finished epoch 81, train loss 0.3805, test loss 0.4422,            train acc 0.8333, test acc 0.8006
# Finished epoch 82, train loss 0.3815, test loss 0.4434,            train acc 0.8324, test acc 0.7996
# Finished epoch 83, train loss 0.3825, test loss 0.4484,            train acc 0.8317, test acc 0.7965
# Finished epoch 84, train loss 0.3790, test loss 0.4432,            train acc 0.8341, test acc 0.8002
# Finished epoch 85, train loss 0.3775, test loss 0.4422,            train acc 0.8348, test acc 0.8007
# Finished epoch 86, train loss 0.3788, test loss 0.4445,            train acc 0.8338, test acc 0.7991
# Finished epoch 87, train loss 0.3784, test loss 0.4471,            train acc 0.8340, test acc 0.7978
# Finished epoch 88, train loss 0.3755, test loss 0.4417,            train acc 0.8359, test acc 0.8014
# Finished epoch 89, train loss 0.3749, test loss 0.4423,            train acc 0.8361, test acc 0.8008
# Finished epoch 90, train loss 0.3758, test loss 0.4455,            train acc 0.8354, test acc 0.7987
# Finished epoch 91, train loss 0.3747, test loss 0.4437,            train acc 0.8361, test acc 0.8003
# Finished epoch 92, train loss 0.3728, test loss 0.4407,            train acc 0.8372, test acc 0.8020
# Finished epoch 93, train loss 0.3724, test loss 0.4422,            train acc 0.8373, test acc 0.8011
# Finished epoch 94, train loss 0.3727, test loss 0.4420,            train acc 0.8370, test acc 0.8012
# Finished epoch 95, train loss 0.3719, test loss 0.4401,            train acc 0.8375, test acc 0.8023
# Finished epoch 96, train loss 0.3707, test loss 0.4398,            train acc 0.8382, test acc 0.8025
# Finished epoch 97, train loss 0.3701, test loss 0.4394,            train acc 0.8384, test acc 0.8028
# Finished epoch 98, train loss 0.3701, test loss 0.4389,            train acc 0.8384, test acc 0.8029
# Finished epoch 99, train loss 0.3693, test loss 0.4369,            train acc 0.8388, test acc 0.8043

# %%
# plot
fig, ax = plt.subplots(1, 2, figsize=(12, 4))
ax[0].plot(losses_train, label='train')
ax[0].plot(losses_test, label='test')
ax[0].set_xlabel('Epoch')
ax[0].set_ylabel('Loss')
ax[0].set_title('Training Loss vs Test Loss')
ax[0].legend()
ax[1].plot(acc_train, label='train')
ax[1].plot(acc_test, label='test')
ax[1].set_xlabel('Epoch')
ax[1].set_ylabel('Accuracy')
ax[1].set_title('Training Accuracy vs Test Accuracy')
ax[1].legend()
plt.show()

# %%
# plot a prediction
y_pred = predict(model, X_test)

idx = np.random.randint(0, len(y_pred))
dice_score = dice(y_pred[idx].int(), torch.argmax(Y_test[idx], dim=0).int(), num_classes=2)
print(dice_score)

fig, ax = plt.subplots(1, 2, figsize=(10, 5))
ax[0].imshow(y_pred[idx].cpu().squeeze().numpy(), cmap='gray')
ax[0].set_title(f'Prediction (Dice Score: {dice_score:.4f})')
ax[0].axis('off')
ax[1].imshow(torch.argmax(Y_test[idx], dim=0).cpu().squeeze().numpy(), cmap='gray')
ax[1].set_title('Ground Truth')
ax[1].axis('off')
plt.show()
# Out:
# tensor(0.8598, device='cuda:0')

# %%
#cnn with weight decay - 1e-5
model_1 = CNN()
model_1 = model_1.to(device)
print(model_1)

n_epochs = 100
learning_rate = 0.001
batch_size = 10

loss_fn   = nn.CrossEntropyLoss(reduction='mean')
optimizer_1 = optim.Adam(model_1.parameters(), lr=learning_rate, weight_decay=1e-5)
losses_train_1, losses_test_1, acc_train_1, acc_test_1 = model_train(model_1, X_train, Y_train, X_test, Y_test, n_epochs, loss_fn, optimizer_1, batch_size)

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 4))
ax[0].plot(losses_train_1, label='train')
ax[0].plot(losses_test_1, label='test')
ax[0].set_xlabel('Epoch')
ax[0].set_ylabel('Loss')
ax[0].set_title('Training Loss vs Test Loss')
ax[0].legend()
ax[1].plot(acc_train_1, label='train')
ax[1].plot(acc_test_1, label='test')
ax[1].set_xlabel('Epoch')
ax[1].set_ylabel('Accuracy')
ax[1].set_title('Training Accuracy vs Test Accuracy')
ax[1].legend()
plt.show()

# %%
# cnn with dropout - 0.2
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Sequential(         
            nn.Conv2d(
                in_channels=3,              
                out_channels=32,            
                kernel_size=3,              
                stride=1,                   
                padding=1,                  
            ),                              
            nn.ReLU(),                      
            nn.MaxPool2d(kernel_size=2, stride=2),  
            nn.ConvTranspose2d(32, 64, 3, 2, 1, 1),  
        )
        self.dropout = nn.Dropout2d(0.2)
        self.conv2 = nn.Sequential(         
            nn.Conv2d(64, 32, 3, 1, 1),     
            nn.ReLU(),                      
            nn.MaxPool2d(2),
            nn.ConvTranspose2d(32, 64, 3, 2, 1, 1),              
        )
        self.dropout = nn.Dropout2d(0.2)
        self.conv3 = nn.Sequential(         
            nn.Conv2d(64, 32, 3, 1, 1),     
            nn.ReLU(),                      
        )
        # 1*1 convolution kernel
        self.out = nn.Conv2d(32, out_channels=2, kernel_size=(1, 1), stride=(1, 1), padding=(0, 0), bias=False)
    def forward(self, x):
        x = self.conv1(x)
        x = self.dropout(x)
        x = self.conv2(x)
        x = self.dropout(x)
        x = self.conv3(x)
        
        output = self.out(x)
        return output
model_2 = CNN()
model_2 = model_2.to(device)
print(model_2)

n_epochs = 100
learning_rate = 0.001
batch_size = 10

loss_fn   = nn.CrossEntropyLoss(reduction='mean')
optimizer = optim.Adam(model_2.parameters(), lr=learning_rate)
losses_train_2, losses_test_2, acc_train_2, acc_test_2 = model_train(model_2, X_train, Y_train, X_test, Y_test,
                                                            n_epochs=n_epochs,
                                                            loss_fn=loss_fn,
                                                            optimizer=optimizer,
                                                            batch_size=batch_size)

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 4))
ax[0].plot(losses_train_2, label='train')
ax[0].plot(losses_test_2, label='test')
ax[0].set_xlabel('Epoch')
ax[0].set_ylabel('Loss')
ax[0].set_title('Training Loss vs Test Loss')
ax[0].legend()
ax[1].plot(acc_train_2, label='train')
ax[1].plot(acc_test_2, label='test')
ax[1].set_xlabel('Epoch')
ax[1].set_ylabel('Accuracy')
ax[1].set_title('Training Accuracy vs Test Accuracy')
ax[1].legend()
plt.show()

# %%
# cnn with batch normalization
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Sequential(         
            nn.Conv2d(
                in_channels=3,              
                out_channels=32,            
                kernel_size=3,              
                stride=1,                   
                padding=1,                  
            ), 
            nn.BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),                             
            nn.ReLU(),                      
            nn.MaxPool2d(kernel_size=2, stride=2),  
            nn.ConvTranspose2d(32, 64, 3, 2, 1, 1),  
        )
        self.conv2 = nn.Sequential(         
            nn.Conv2d(64, 32, 3, 1, 1),  
            nn.BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),   
            nn.ReLU(),                      
            nn.MaxPool2d(2),
            nn.ConvTranspose2d(32, 64, 3, 2, 1, 1),              
        )
        self.conv3 = nn.Sequential(         
            nn.Conv2d(64, 32, 3, 1, 1),
            nn.BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True),    
            nn.ReLU(),                      
        )
        # 1*1 convolution kernel
        self.out = nn.Conv2d(32, out_channels=2, kernel_size=(1, 1), stride=(1, 1), padding=(0, 0), bias=False)
    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        
        output = self.out(x)
        return output
model_3 = CNN()
model_3 = model_3.to(device)
print(model_3)

n_epochs = 100
learning_rate = 0.001
batch_size = 10

loss_fn   = nn.CrossEntropyLoss(reduction='mean')
optimizer = optim.Adam(model_3.parameters(), lr=learning_rate)
losses_train_3, losses_test_3, acc_train_3, acc_test_3 = model_train(model_3, X_train, Y_train, X_test, Y_test,
                                                            n_epochs=n_epochs,
                                                            loss_fn=loss_fn,
                                                            optimizer=optimizer,
                                                            batch_size=batch_size)

# %%
fig, ax = plt.subplots(1, 2, figsize=(12, 4))
ax[0].plot(losses_train_3, label='train')
ax[0].plot(losses_test_3, label='test')
ax[0].set_xlabel('Epoch')
ax[0].set_ylabel('Loss')
ax[0].set_title('Training Loss vs Test Loss')
ax[0].legend()
ax[1].plot(acc_train_3, label='train')
ax[1].plot(acc_test_3, label='test')
ax[1].set_xlabel('Epoch')
ax[1].set_ylabel('Accuracy')
ax[1].set_title('Training Accuracy vs Test Accuracy')
ax[1].legend()
plt.show()

# %%
# deeper cnn model - resenet50

def model_train(model, X_train, Y_train, X_test, Y_test, n_epochs,  loss_fn, optimizer, batch_size=5):
    losses_train, losses_test, acc_train, acc_test = [], [], [], []
    batch_start = torch.arange(0, len(X_train), batch_size)

    model.train()
    for epoch in range(n_epochs):
        for start in batch_start:
            X_batch = X_train[start:start+batch_size]
            Y_batch = Y_train[start:start+batch_size]
            y_pred = model(X_batch)['out']
            loss = loss_fn(y_pred, Y_batch)

            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
        
        with torch.no_grad():
            y_pred_train = model(X_train)['out']
            y_pred_test = model(X_test)['out']
        losses_train.append(loss_fn(y_pred_train, Y_train).item())
        losses_test.append(loss_fn(y_pred_test, Y_test).item())
        acc_train.append(acc_fn(y_pred_train, Y_train).item())
        acc_test.append(acc_fn(y_pred_test, Y_test).item())
        print(f'Finished epoch {epoch}, train loss {losses_train[-1]:.4f}, test loss {losses_test[-1]:.4f}, \
           train acc {acc_train[-1]:.4f}, test acc {acc_test[-1]:.4f}')
    return losses_train, losses_test, acc_train, acc_test

def predict(model, X):
    model.eval()
    with torch.no_grad():
        y_pred = model(X)['out']
        y_pred = torch.argmax(torch.softmax(y_pred, dim=1), dim=1)
    return y_pred


model = torchvision.models.segmentation.deeplabv3_resnet50(pretrained=True)
model.classifier[4] = nn.Conv2d(256, 2, kernel_size=(1, 1), stride=(1, 1))
model = model.to(device)
print(model)

n_epochs = 100
learning_rate = 0.001
batch_size = 10

loss_fn   = nn.CrossEntropyLoss(reduction='mean')
optimizer = optim.Adam(model.parameters(), lr=learning_rate)
losses_train, losses_test, acc_train, acc_test = model_train(model, X_train, Y_train, X_test, Y_test,
                                                            n_epochs=n_epochs,
                                                            loss_fn=loss_fn,
                                                            optimizer=optimizer,
                                                            batch_size=batch_size)

fig, ax = plt.subplots(1, 2, figsize=(12, 4))
ax[0].plot(losses_train, label='train')
ax[0].plot(losses_test, label='test')
ax[0].set_xlabel('Epoch')
ax[0].set_ylabel('Loss')
ax[0].set_title('Training Loss vs Test Loss')
ax[0].legend()
ax[1].plot(acc_train, label='train')
ax[1].plot(acc_test, label='test')
ax[1].set_xlabel('Epoch')
ax[1].set_ylabel('Accuracy')
ax[1].set_title('Training Accuracy vs Test Accuracy')
ax[1].legend()
plt.show()
